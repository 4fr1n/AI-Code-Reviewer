# %%
# !python fine_tune_codebert.py
# Out:
# Using device: cuda
# Loading training data …
#   908 rows loaded
#
# Class weights (inverse frequency):
#   bug         : 0.560
#   style       : 1.713
#   performance : 4.656
#   security    : 7.567
#   ok          : 0.438
#
# ...
# config.json: 100% 498/498 [00:00<00:00, 1.56MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 122kB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 32.4MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 103MB/s]
# special_tokens_map.json: 100% 150/150 [00:00<00:00, 905kB/s]
#
# ...
# FOLD 1/5
# ...
# pytorch_model.bin: 100% 499M/499M [00:06<00:00, 79.5MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 32829.87it/s]
# model.safetensors: 100% 499M/499M [00:05<00:00, 96.9MB/s]
#   Fold 1 · Epoch 1/10 · Loss: 1.5888
#   Fold 1 · Epoch 2/10 · Loss: 1.4814
#   Fold 1 · Epoch 3/10 · Loss: 1.2588
#   Fold 1 · Epoch 4/10 · Loss: 0.9712
#   Fold 1 · Epoch 5/10 · Loss: 0.6800
#   Fold 1 · Epoch 6/10 · Loss: 0.3096
#   Fold 1 · Epoch 7/10 · Loss: 0.1893
# ...
